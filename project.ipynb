# %% [markdown]
# <a href="https://colab.research.google.com/github/Sujal101/project-/blob/main/project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import kagglehub
import os
import pandas as pd
path = kagglehub.dataset_download(
    "spscientist/students-performance-in-exams"
)
print(os.listdir(path))
file_path = os.path.join(path,"StudentsPerformance.csv") # Corrected filename here
df = pd.read_csv(file_path)
print(df["math score"].describe())
# Out:
# Using Colab cache for faster access to the 'students-performance-in-exams' dataset.
# ['StudentsPerformance.csv']
# count    1000.00000
# mean       66.08900
# std        15.16308
# min         0.00000
# 25%        57.00000
# 50%        66.00000
# 75%        77.00000
# max       100.00000
# Name: math score, dtype: float64

# %%
import kagglehub
import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
path = kagglehub.dataset_download(
    "spscientist/students-performance-in-exams"
)
print(os.listdir(path))
file_path = os.path.join(path,"StudentsPerformance.csv") # Corrected filename here
df = pd.read_csv(file_path)
plt.figure(figsize=(8,5))
sns.histplot(df['math score'], kde=True)
plt.title("Math Score Distribution")
plt.show()
# Out:
# Using Colab cache for faster access to the 'students-performance-in-exams' dataset.
# ['StudentsPerformance.csv']

# %%
import kagglehub
import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
path = kagglehub.dataset_download(
    "spscientist/students-performance-in-exams"
)
print(os.listdir(path))
file_path = os.path.join(path,"StudentsPerformance.csv")
plt.figure(figsize=(8,5))
sns.boxplot(data=df,
            x='gender',
            y='math score')

plt.title("Math Score by Gender")
plt.show()
# Out:
# Using Colab cache for faster access to the 'students-performance-in-exams' dataset.
# ['StudentsPerformance.csv']

# %%
import kagglehub
import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
path = kagglehub.dataset_download(
    "spscientist/students-performance-in-exams"
)
print(os.listdir(path))
file_path = os.path.join(path,"StudentsPerformance.csv")
df = pd.read_csv(file_path)

plt.figure(figsize=(12,5))

sns.barplot(
    data=df,
    x='parental level of education',
    y='math score'
)

plt.xticks(rotation=45)
plt.title("Parent Education vs Math Score")
plt.show()
# Out:
# Using Colab cache for faster access to the 'students-performance-in-exams' dataset.
# ['StudentsPerformance.csv', '.nfs00000000ac7f500600000084']

# %%
import kagglehub
import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
path = kagglehub.dataset_download(
    "spscientist/students-performance-in-exams"
)
print(os.listdir(path))
file_path = os.path.join(path,"StudentsPerformance.csv")
df = pd.read_csv(file_path)
scores = df[['math score',
             'reading score',
             'writing score']]

corr = scores.corr()

plt.figure(figsize=(6,5))

sns.heatmap(
    corr,
    annot=True,
    cmap='coolwarm'
)

plt.title("Correlation Heatmap")
plt.show()
# Out:
# Using Colab cache for faster access to the 'students-performance-in-exams' dataset.
# ['StudentsPerformance.csv']

# %%
import kagglehub
import os
import pandas as pd
import matplotlib.pyplot as plt
path = kagglehub.dataset_download(
    "spscientist/students-performance-in-exams"
)
print(os.listdir(path))
file_path = os.path.join(path,"StudentsPerformance.csv")
df = pd.read_csv(file_path)
gender_counts = df["gender"].value_counts()

# Pie Chart

plt.pie(
    gender_counts,
    labels=gender_counts.index,
    autopct="%1.1f%%",
    startangle=90
)

plt.title("Distribution of Students by Gender")
plt.show()
print(df.head())
# Out:
# Using Colab cache for faster access to the 'students-performance-in-exams' dataset.
# ['StudentsPerformance.csv']
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
import kagglehub
import os
import pandas as pd
import matplotlib.pyplot as plt
path = kagglehub.dataset_download(
    "spscientist/students-performance-in-exams"
)
print(os.listdir(path))
file_path = os.path.join(path,"StudentsPerformance.csv")
df = pd.read_csv(file_path)
plt.figure(figsize=(8,5))
plt.hist(df["math score"], bins=10)
plt.title("Distribution of Math Scores")
plt.xlabel("Math Score")
plt.ylabel("Frequency")
plt.show()
# Out:
# Using Colab cache for faster access to the 'students-performance-in-exams' dataset.
# ['StudentsPerformance.csv']

# %%
import kagglehub
import os
import pandas as pd
import matplotlib.pyplot as plt
path = kagglehub.dataset_download(
    "spscientist/students-performance-in-exams"
)
print(os.listdir(path))
file_path = os.path.join(path,"StudentsPerformance.csv")
df = pd.read_csv(file_path)
gender_counts = df["gender"].value_counts()

plt.figure(figsize=(6,4))
plt.bar(gender_counts.index, gender_counts.values)
plt.title("Gender Distribution")
plt.xlabel("Gender")
plt.ylabel("Count")
plt.show()
# Out:
# Using Colab cache for faster access to the 'students-performance-in-exams' dataset.
# ['StudentsPerformance.csv']
